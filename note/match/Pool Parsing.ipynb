# %%
## Basic stuff
# %load_ext autoreload
# %autoreload

###########################################################################
## Pool Parsing
###########################################################################
from poolParsing import masterPoolPrimaryParser, masterPoolExtraParser, masterPoolCreditParser
from poolParsing import masterPoolSpotifyAPIParser, masterPoolDiscogsAPIParser, masterPoolDeezerAPIParser, masterPoolGeniusAPIParser
from poolParsing import masterPoolUnofficialParser, masterPoolMetadata, masterPoolSongParser, masterPoolCompositionParser
from masterDBCreator import masterDBCreator
from masterDBGate import masterDBGate
from masterUtils import masterUtils

###########################################################################
## Warnings
###########################################################################
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.filterwarnings("ignore", category=FutureWarning) 

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))
#IPython.Cell.options_default.cm_config.lineNumbers = true;

# %%
mdbGate = masterDBGate()

# %% [markdown]
# # Pool Parsing

# %%
db = "AlbumOfTheYear"

# %%
from dbArtistsMetadata import dbArtistsMetadata
from dbArtistsParse import dbArtistsPrimary
from dbArtistsAllMusic import dbArtistsAllMusic
from dbArtistsAlbumOfTheYear import dbArtistsAlbumOfTheYear
dbAP = dbArtistsPrimary(dbArtistsAlbumOfTheYear())
#dbAP.parse(modVal=79, force=True, expr="< 0 Days")
dbMeta = dbArtistsMetadata(dbArtistsAlbumOfTheYear())
dbMeta.parse(modVal=79, force=True, expr="< 0 Days")

# %%
# %autoreload
#masterPoolPrimaryParser(db, modVals=list(range(100)), force=False, numProcs=3)
masterPoolMetadata(db, numProcs=3)
mdbc = masterDBCreator(db)
mdbc.createArtistIDMap()
mdbc.createArtistIDAlbumsMap()
mdbc.createArtistDataForMatch()

# %% [markdown]
# # Spotify

# %%
db = "Spotify"
masterPoolSpotifyAPIParser(db, modVals=list(range(100)), force=False, numProcs=3)
masterPoolMetadata(db, modVals=list(range(100)), numProcs=3)

from masterDBCreator import masterDBCreator
mdbc = masterDBCreator(db)
mdbc.createArtistIDMap()
mdbc.createArtistIDAlbumsMap()
mdbc.createArtistDataForMatch()

# ModVal=100        530953  2694789
# ModVal=100        530953  3347041

# %% [markdown]
# # Genius API

# %%
db = "GeniusAPI"
masterPoolGeniusAPIParser(db, modVals=list(range(100)), force=False, numProcs=3)
masterPoolMetadata(db, modVals=list(range(100)), numProcs=3)

from masterDBCreator import masterDBCreator
mdbc = masterDBCreator(db)
mdbc.createArtistIDMap()
mdbc.createArtistIDAlbumsMap()
mdbc.createArtistDataForMatch()

# ModVal=100         96834        0
# ModVal=100        101835        0
# ModVal=100        104336        0

# %%
mu = masterUtils()
modValData = mu.getDisc("GeniusAPI").getDBModValData(0)

# %%
modValData['100'].show()

# %%
db = "GeniusAPI"
#from dbArtistsDeezerAPI import dbArtistsDeezerAPI
#from dbArtistsParse import dbArtistsPickleAPI
#masterPoolPrimaryParser(db, modVals=list(range(100)), force=False, numProcs=3)
masterPoolMetadata(db, modVals=list(range(1)), numProcs=1)

# %% [markdown]
# # Deezer API

# %%
db = "DeezerAPI"
masterPoolMetadata(db, modVals=list(range(100)), numProcs=3)

from masterDBCreator import masterDBCreator
mdbc = masterDBCreator(db)
mdbc.createArtistIDMap()
mdbc.createArtistIDAlbumsMap()
mdbc.createArtistDataForMatch()

# ModVal=100        899358  3184806
# ModVal=100       1048553  3681129
# ModVal=100       1069560 21177861

# %%
from fileIO import fileIO
tmp = fileIO().get("/Users/tgadfort/Music/Discog/db-deezer/ArtistIDToSearchName.p")

# %% [markdown]
# # LastFM API

# %%
db = "LastFMAPI"
from dbArtistsLastFMAPI import dbArtistsLastFMAPI
from dbArtistsParse import dbArtistsPickleHTML
dbAP = dbArtistsPickleHTML(dbArtistsLastFMAPI())
dbAP.parse(expr='< 7 Days', force=False)

masterPoolPrimaryParser(db, modVals=list(range(100)), force=False, numProcs=3)
masterPoolMetadata(db, modVals=list(range(100)), numProcs=3)

from masterDBCreator import masterDBCreator
mdbc = masterDBCreator(db)
mdbc.createArtistIDMap()
mdbc.createArtistIDAlbumsMap()
mdbc.createArtistDataForMatch()


# ModVal=100         69915 24593747
# ModVal=100        121187 29780737

# %% [markdown]
# # RateYourMusic

# %%
db = "MusicBrainz"
from masterDBCreator import masterDBCreator
mdbc = masterDBCreator(db)
mdbc.createArtistDataForMatch()

# %%
db = "RateYourMusic"
from masterDBGate import masterDBGate
from dbArtistsParse import dbArtistsPrimary, dbArtistsHTML
mdbGate = masterDBGate()
dbAP    = dbArtistsHTML(mdbGate.getDBGate(db))
dbAP.parse(expr="< 1 Hours", force=False)

masterPoolPrimaryParser(db, modVals=list(range(100)), force=False, numProcs=3)
masterPoolMetadata(db, modVals=list(range(100)), numProcs=3)

from masterDBCreator import masterDBCreator
mdbc = masterDBCreator(db)
mdbc.createArtistIDMap()
mdbc.createArtistIDAlbumsMap()
mdbc.createArtistDataForMatch()

# ModVal=100         45836  1319924
# ModVal=100         45920  1320390

# %% [markdown]
# # Genius

# %%
db = "Genius"
from masterDBGate import masterDBGate
masterPoolPrimaryParser(db, modVals=list(range(100)), numProcs=3, force=False)
masterPoolMetadata(db, modVals=list(range(100)), numProcs=3)

from masterDBCreator import masterDBCreator
mdbc = masterDBCreator(db)
mdbc.createArtistIDMap()
mdbc.createArtistIDAlbumsMap()
mdbc.createArtistDataForMatch()

#ModVal=100        163639  1439989

# %% [markdown]
# # AllMusic

# %%
db = "AllMusic"
from masterDBGate import masterDBGate
#masterPoolPrimaryParser(db, modVals=list(range(100)), numProcs=3, force=True)
#masterPoolCreditParser(db, modVals=list(range(100)), numProcs=3, force=True)
#masterPoolCompositionParser(db, modVals=list(range(3,100)), numProcs=3, force=True)
#masterPoolSongParser(db, modVals=list(range(100)), numProcs=3, force=True)
masterPoolMetadata(db, modVals=list(range(100)), numProcs=3)

from masterDBCreator import masterDBCreator
mdbc = masterDBCreator(db)
mdbc.createArtistIDMap()
mdbc.createArtistIDAlbumsMap()
mdbc.createArtistDataForMatch()

# %% [markdown]
# # KWorbiTunes

# %%
masterPoolPrimaryParser("KWorbiTunes", modVals=list(range(100)), force=False, numProcs=3)
masterPoolMetadata("KWorbiTunes", modVals=list(range(100)), numProcs=3)

from masterDBCreator import masterDBCreator
mdbc = masterDBCreator("KWorbiTunes")
mdbc.createArtistIDMap()
mdbc.createArtistIDAlbumsMap()

# %%
mdbc = masterDBCreator("KWorbiTunes")
mdbc.createArtistIDMap()
mdbc.createArtistIDAlbumsMap()
mdbc.createArtistDataForMatch()

# %%
dbs = masterDBGate().getDBs()
for db in dbs:
    mdbc = masterDBCreator(db)
    #mdbc.createArtistIDMap()
    #mdbc.createArtistIDAlbumsMap()
    mdbc.createArtistDataForMatch()

# %% [markdown]
# # SpotifyCharts

# %%
masterPoolMetadata("SpotifyCharts", modVals=list(range(100)), numProcs=3)

from masterDBCreator import masterDBCreator
mdbc = masterDBCreator("SpotifyCharts")
mdbc.createArtistIDMap()
mdbc.createArtistIDAlbumsMap()
mdbc.createArtistDataForMatch()

# %%
from masterDBCreator import masterDBCreator
mdbc = masterDBCreator("SpotifyCharts")

# %%
mdbc.createArtistIDMap()
mdbc.createArtistIDAlbumsMap()
mdbc.createArtistDataForMatch()

# %% [markdown]
# # Discogs API

# %%
from dbArtistsParse import dbArtistsDiscogsAPI
from dbArtistsDiscogs import dbArtistsDiscogs
for modVal in range(1):
    dbAP = dbArtistsDiscogsAPI(dbArtistsDiscogs())
    dbAP.parse(modVal, expr="< 0 Days")
    #dbAP.parseSearch(modVal, expr="< 0 Days")

# %%
from dbArtistsParse import dbArtistsDiscogsAPI
from dbArtistsDiscogs import dbArtistsDiscogs
for modVal in range(7,100):
    dbAP = dbArtistsDiscogsAPI(dbArtistsDiscogs())
    dbAP.parse(modVal, expr="< 0 Days")

# %%
from dbArtistsMetadata import dbArtistsMetadata
from dbArtistsDiscogs import dbArtistsDiscogs
for modVal in range(1):
    dbAP = dbArtistsMetadata(dbArtistsDiscogs())
    dbAP.parse(modVal, expr="< 0 Days")

# %%
db = "Discogs"
#masterPoolDiscogsAPIParser(db, modVals=list(range(7,100)), force=False, numProcs=3)
masterPoolMetadata(db, modVals=list(range(100)), numProcs=3)

from masterDBCreator import masterDBCreator
mdbc = masterDBCreator(db)
mdbc.createArtistIDMap()
mdbc.createArtistIDAlbumsMap()
mdbc.createArtistDataForMatch()
