# %%
# %load_ext autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100`% !important; }</style>"))
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
# Out:
# <style>.container { width:100`% !important; }</style>

# %%
from match import SingleMatchDB, SingleCrossMatchDB, PanDBMatch, MatchReq, NameReq, AlbumReq, MatchDBDataIO
from master import MasterMetas, MusicDBPermDir, MasterDBs
from ioutils import FileIO
io = FileIO()

# %%
minL = 5
maxL = 6

minA = 15
maxA = 1500000000

dbs=['Discogs', 'Spotify', 'LastFM', 'Genius', 'RateYourMusic', 'MetalArchives', 'Deezer', 'AllMusic', 'MusicBrainz',
     'AlbumOfTheYear', 'SetListFM', 'Beatport', 'Traxsource', 'MyMixTapez', 'ClassicalArchives']
baseDB    = "RateYourMusic" # Done
baseDB    = "MusicBrainz"
baseDB    = "Discogs"
#compDB    = "LastFM" # Not Done
#compDB    = "Discogs" # Done Done
compDB    = "MetalArchives" # Done Done
compDB    = "Deezer" # Done Done
compDB    = "Beatport" # Done Done Done
compDB    = "Genius" # Done Done Done
compDB    = "AlbumOfTheYear" # Done Done Done
compDB    = "Traxsource" # Done Done Done
compDB    = "Spotify" # Done Done

baseReq   = {baseDB: MatchReq(NameReq(min=minL, max=maxL), AlbumReq(min=minA, max=maxA))}
compReq   = {compDB: MatchReq(NameReq(min=minL-5, max=maxL+5), AlbumReq(min=3))}

matchReqs  = {**baseReq, **compReq}
mediaTypes = list(MasterMetas().getMedias().values())
reqs       = {"Media": mediaTypes, "ChunkSize": 3000, "Reqs": matchReqs, "Mask": (baseDB,compDB), "NPart": 3, "Match": {"Artist": 0.85, "Medium": 2, "Tight": 1}}


if False:
    baseIO = MatchDBDataIO(db=baseDB, mediaTypes=reqs["Media"], mask=(baseDB,compDB), verbose=True, base=True)
    baseIO.loadNames()
    baseIO.setAvailableNames(reqs["Reqs"][baseDB])

# %%
smdb = SingleMatchDB(baseDB=baseDB, compareDB=compDB, reqs=reqs)
smdb.match()
smdb.save()
del smdb


mdbpd = MusicDBPermDir()
mres  = io.get(mdbpd.getMatchPermPath().join("primaryMatch.p"))
crossreqs  = {"Media": mediaTypes, "Reqs": {baseDB: MatchReq(AlbumReq(min=2))}, "Mask": baseDB, "NPart": 3, "Match": {"Artist": 0.85, "Medium": 2, "Tight": 1}}
scmdb = SingleCrossMatchDB(baseDB, mres, crossreqs, verbose=True)
scmdb.match()
scmdb.save()
del scmdb
# Out:
# *******************************************************************************************************************************************************************************
# **                                                                             SingleMatchDB()                                                                               **
# *******************************************************************************************************************************************************************************
# | ChunkSize ==> 3000
#   MatchDBData(Discogs):
#   MatchDBData(Spotify):
# Process [Matching [Discogs] Against [Spotify]] Start    ==> Time Is 2022-05-19 20:00:25
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# --                                                                             Discogs()                                                                                     --
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#   Process [Loading Discogs Artist Names] Start    ==> Time Is 2022-05-19 20:00:25
#    ==> Loading Names Data
#      ==> Found  610364 Artists Basic Data In Discogs DB
#        ==> Masking Artists
#      ==> Found  792863 Previously Matched Discogs Artists
#      ==> Found  348161 Available Artists In Discogs DB
#      ==> Found  698374 Previously Matched Discogs Artists Without A Spotify Match
#      ==> Found  268094 Available Artists In Discogs DB
#      ==> Cut[Media]           268094 Artists With [2/3736] Min/Max
#      ==> Cut[MediaLen]        151616 Artists With [15/3736] Min/Max
#      ==> Cut[Names]           268094 Artists With [0/93] Min/Max
#      ==> Cut[NamesLen]         10673 Artists With [5/5] Min/Max
#      ==> Cut[Final]             5652 Artists With [/] Min/Max
#   Process [Loading Discogs Artist Names] Ran For 23 Seconds    ==> Time Is 2022-05-19 20:00:48
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# --                                                                             Spotify()                                                                                     --
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#   Process [Loading Spotify Artist Names] Start    ==> Time Is 2022-05-19 20:00:48
#    ==> Loading Names Data
#      ==> Found  248896 Artists Basic Data In Spotify DB
#        ==> Masking Artists
#      ==> Found  120436 Previously Cross Matched Artists
#      ==> Found  143428 Artists In Spotify DB
#      ==> Found  143428 Available Artists In Spotify DB
#      ==> Cut[Media]           143428 Artists With [2/1567] Min/Max
#      ==> Cut[MediaLen]        118330 Artists With [3/1567] Min/Max
#      ==> Cut[Names]           143428 Artists With [1/140] Min/Max
#      ==> Cut[NamesLen]         63736 Artists With [1/10] Min/Max
#      ==> Cut[Final]            53685 Artists With [/] Min/Max
#   Process [Loading Spotify Artist Names] Ran For 6 Seconds    ==> Time Is 2022-05-19 20:00:54
# Splitting Discogs Names Into 5652/3000 ==> 2 Chunks
#
# ...............................................................................................................................................................................
# ..                                                                             Chunk 0/2()                                                                                   ..
# ...............................................................................................................................................................................
#   Process [String Matching 2826 [Discogs] x 53685 [Spotify] Artist Names] Start    ==> Time Is 2022-05-19 20:00:54
# 100%|██████████| 942/942 [00:33<00:00, 28.51it/s]
# 100%|██████████| 942/942 [00:33<00:00, 28.38it/s]
# 100%|██████████| 942/942 [00:33<00:00, 27.92it/s]
#   Process [String Matching 2826 [Discogs] x 53685 [Spotify] Artist Names] Ran For 1 Minute and 14 Seconds    ==> Time Is 2022-05-19 20:02:08
#      ==> Found 2826 Name Results
#      ==> Found 1673 Artists With One Or More Matches
#      ==> Found 5207 Possible Matches
#     Process [Loading Discogs Media Data] Start    ==> Time Is 2022-05-19 20:02:09
#      ==> Found  610364 Artists Media Data In Discogs DB
#     Process [Loading Discogs Media Data] Ran For 1 Minute and 3 Seconds    ==> Time Is 2022-05-19 20:03:12
#     Process [Loading Spotify Media Data] Start    ==> Time Is 2022-05-19 20:03:12
#      ==> Found    3740 Artists Media Data In Spotify DB
#     Process [Loading Spotify Media Data] Ran For 11 Seconds    ==> Time Is 2022-05-19 20:03:23
#   Process [String Matching 5207 [Discogs] Album Names] Start    ==> Time Is 2022-05-19 20:03:24
#       Process [Matching 5207 Artists' Albums] Start    ==> Time Is 2022-05-19 20:03:25
#       Process [Matching 5207 Artists' Albums] Ran For 1 Minute and 26 Seconds    ==> Time Is 2022-05-19 20:04:51
# ==== Match Results ====
# Pure     150
# Sole      48
# Poor      46
# Great     24
# Near      16
# Low       14
# Good      12
# Loose      1
# Name: MediaQuality, dtype: int64
# ==== Match Results ====
# Pure     150
# Sole      48
# Poor      46
# Great     24
# Near      16
# Low       14
# Good      12
# Loose      1
# Name: MediaQuality, dtype: int64
#   Process [String Matching 5207 [Discogs] Album Names] Ran For 1 Minute and 59 Seconds    ==> Time Is 2022-05-19 20:05:23
#
# ...............................................................................................................................................................................
# ..                                                                             Chunk 1/2()                                                                                   ..
# ...............................................................................................................................................................................
#   Process [String Matching 2826 [Discogs] x 53685 [Spotify] Artist Names] Start    ==> Time Is 2022-05-19 20:05:23
# 100%|██████████| 942/942 [00:32<00:00, 29.06it/s]
# 100%|██████████| 942/942 [00:32<00:00, 28.72it/s]
# 100%|██████████| 942/942 [00:32<00:00, 28.59it/s]
#   Process [String Matching 2826 [Discogs] x 53685 [Spotify] Artist Names] Ran For 1 Minute and 15 Seconds    ==> Time Is 2022-05-19 20:06:38
#      ==> Found 2826 Name Results
#      ==> Found 1598 Artists With One Or More Matches
#      ==> Found 4659 Possible Matches
#     Process [Loading Discogs Media Data] Start    ==> Time Is 2022-05-19 20:06:38
#     Process [Loading Discogs Media Data] Ran For     ==> Time Is 2022-05-19 20:06:39
#     Process [Loading Spotify Media Data] Start    ==> Time Is 2022-05-19 20:06:39
#      ==> Found    3268 Artists Media Data In Spotify DB
#     Process [Loading Spotify Media Data] Ran For 10 Seconds    ==> Time Is 2022-05-19 20:06:49
#   Process [String Matching 4659 [Discogs] Album Names] Start    ==> Time Is 2022-05-19 20:06:52
#       Process [Matching 4659 Artists' Albums] Start    ==> Time Is 2022-05-19 20:06:53
#       Process [Matching 4659 Artists' Albums] Ran For 24 Seconds    ==> Time Is 2022-05-19 20:07:17
# ==== Match Results ====
# Pure     242
# Sole      85
# Poor      72
# Great     46
# Near      22
# Low       20
# Good      17
# Loose      3
# Name: MediaQuality, dtype: int64
# ==== Match Results ====
# Pure     242
# Sole      85
# Poor      72
# Great     46
# Near      22
# Low       20
# Good      17
# Loose      3
# Name: MediaQuality, dtype: int64
#   Process [String Matching 4659 [Discogs] Album Names] Ran For 44 Seconds    ==> Time Is 2022-05-19 20:07:37
# Process [Matching [Discogs] Against [Spotify]] Ran For 7 Minutes and 11 Seconds    ==> Time Is 2022-05-19 20:07:37
# Saving Primary Match Results To /Users/tgadfort/opt/anaconda3/envs/py310/pandb/mdbmatch/primaryMatch.p
# ==== Match Results ====
# By DB:
# Spotify    507
# Name: DB, dtype: int64
# By NameQuality:
# Pure    395
# Near     81
# Good     31
# Name: NameQuality, dtype: int64
# By MediaQuality:
# Pure     242
# Sole      85
# Poor      72
# Great     46
# Near      22
# Low       20
# Good      17
# Loose      3
# Name: MediaQuality, dtype: int64
# Saving Primary Match Names To /Users/tgadfort/opt/anaconda3/envs/py310/pandb/mdbmatch/primaryMatchNames.p
#
# *******************************************************************************************************************************************************************************
# **                                                                             SingleCrossMatchDB()                                                                          **
# *******************************************************************************************************************************************************************************
# Process [Cross Matching [Discogs] Against ['Spotify']] Start    ==> Time Is 2022-05-19 20:07:39
#      ==> Cut[Media]           610364 Artists With [2/5200] Min/Max
#      ==> Cut[MediaLen]        610364 Artists With [2/5200] Min/Max
#      ==> Cut[Final]           610364 Artists With [/] Min/Max
#   Process [String Matching 507 ['Spotify'] x 610364 [Discogs] Artist Names] Start    ==> Time Is 2022-05-19 20:07:57
# 100%|██████████| 169/169 [01:19<00:00,  2.13it/s]
# 100%|██████████| 169/169 [01:19<00:00,  2.12it/s]
# 100%|██████████| 169/169 [01:20<00:00,  2.11it/s]
#      ==> Found 507 Name Results
#      ==> Found 507 Artists With One Or More Matches
#      ==> Found 4801 Possible Matches
#   Process [String Matching 507 ['Spotify'] x 610364 [Discogs] Artist Names] Ran For 4 Minutes and 4 Seconds    ==> Time Is 2022-05-19 20:12:01
#   Process [String Matching 4801 ['Spotify'] Album Names] Start    ==> Time Is 2022-05-19 20:12:01
#       Process [Matching 4801 Artists' Albums] Start    ==> Time Is 2022-05-19 20:12:02

# %%
pdbm = PanDBMatch(baseDB, verbose=True)
pdbm.select(minQual=5)
pdbm.pandbLookupSingle()
pdbm.merge(allownew=False, verbose=False)

# %%
pdbm.mergeMultiRows()

# %%
pdbm = PanDBMatch(baseDB, verbose=True)
pdbm.select(minQual=4, maxQual=5, minName=4)

# %%
pdbm.include("""
23819bce22   |                     Spotify        15zCdn0Gb0GfvXYzbsE1KX        5   4    | GROOVY                                  GROOVY                                  
118614a0c1   |                     Spotify        0FrSB2BRozJUHDBTgmwzse        5   4    | MOTHER                                  MOTHER                                  
e2dbf17694   |                     Spotify        5LIlpl87UuxeN3CNfPMc3l        5   4    | KAYDEE                                  KAYDEE                                  
2555fb671f   |                     Spotify        3NCSHGTxR41APEFSUQ9lQi        5   4    | PRAVDA                                  PRAVDA                                  
97df031460   |                     Spotify        3n31SpYQXw18tVaSaPiK9J        5   4    | MONACA                                  MONACA                                  
1e67b7a682   |                     Spotify        4hPOWy4OfdwNnB8osFESmQ        5   4    | AKANNI                                  AKANNI                                  
a1adac6e4b   |                     Spotify        5btCRpy3MmqEeGcm6PlOrA        5   4    | GEORGE                                  GEORGE                                  
f86912a81e   |                     Spotify        6xkUvC3YM4U0MVcwls7crD        5   4    | BLANCO                                  BLANCO                                  
366cc6b814   |                     Spotify        4zHkR4wQ2p6krlSrz7pZls        5   4    | PORCHA                                  PORCHA                                  
""")
pdbm.pandbLookupSingle()
pdbm.merge(allownew=False, verbose=False)
# Out:
# 23819bce22   | 113279                   Spotify        15zCdn0Gb0GfvXYzbsE1KX                  4    GROOVY                                            GROOVY                                             | 23819bce22
# 118614a0c1   | 12293                    Spotify        0FrSB2BRozJUHDBTgmwzse                  4    MOTHER                                            MOTHER                                             | 118614a0c1
# e2dbf17694   | 300086                   Spotify        5LIlpl87UuxeN3CNfPMc3l                  4    KAYDEE                                            KAYDEE                                             | e2dbf17694
# 2555fb671f   | 300090                   Spotify        3NCSHGTxR41APEFSUQ9lQi                  4    PRAVDA                                            PRAVDA                                             | 2555fb671f
# 97df031460   | 3289669                  Spotify        3n31SpYQXw18tVaSaPiK9J                  4    MONACA                                            MONACA                                             | 97df031460
# 1e67b7a682   | 358493                   Spotify        4hPOWy4OfdwNnB8osFESmQ                  4    AKANNI                                            AKANNI                                             | 1e67b7a682
# a1adac6e4b   | 421187                   Spotify        5btCRpy3MmqEeGcm6PlOrA                  4    GEORGE                                            GEORGE                                             | a1adac6e4b
# f86912a81e   | 57330                    Spotify        6xkUvC3YM4U0MVcwls7crD                  4    BLANCO                                            BLANCO                                             | f86912a81e
# 366cc6b814   | 754044                   Spotify        4zHkR4wQ2p6krlSrz7pZls                  4    PORCHA                                            PORCHA                                             | 366cc6b814
#   ==> Found [9] Matches For [9] [Discogs] IDs From [1] DBs
#   ==> Getting Master ID Lookup
#   ==> Found [9] Known Matches
#   ==> Found [0] Multi Matches
#   ==> Found [0] New Matches
#   ==> Added [9] Known Matches
# Saving Master DataFrame To /Users/tgadfort/opt/anaconda3/envs/py310/pandb/musicdb/manualEntries.p

# %%
pdbm.mergeMultiRows()
# Out:
# Nothing to merge

# %%
pdbm = PanDBMatch(baseDB, verbose=True)
pdbm.select(minQual=2, maxQual=4, minName=4)
# Out:
# *******************************************************************************************************************************************************************************
# **                                                                             PanDBMatch()                                                                                  **
# *******************************************************************************************************************************************************************************
# 00f029ea6a   |                     Spotify        2xMb3TX901tyFs5TPOi1ro        5   2    | Q BASE                                  Q BASE
# cf0f915700   |                     Spotify        40JYLbI7UkALG8X4IAOjgC        5   2    | SANTOS                                  SANTOS
# 2e533da507   |                     Spotify        3RKpqQ3N1VwInnXiOIZcsb        5   2    | NECROS                                  NECROS
# 97fc3dea43   |                     Spotify        2LiAtY86DAtanU7JGYRgtK        5   2    | GALLEN                                  GALLEN
# d791330448   |                     Spotify        4VbG7fLmrfYHmCqerZKBes        5   2    | BASS X                                  BASS X
#   ==> Found [5] Matches For [5] [Discogs] IDs From [1] DBs

# %%
pdbm.include("""
00f029ea6a   |                     Spotify        2xMb3TX901tyFs5TPOi1ro        5   2    | Q BASE                                  Q BASE                                  
cf0f915700   |                     Spotify        40JYLbI7UkALG8X4IAOjgC        5   2    | SANTOS                                  SANTOS                                  
2e533da507   |                     Spotify        3RKpqQ3N1VwInnXiOIZcsb        5   2    | NECROS                                  NECROS                                  
97fc3dea43   |                     Spotify        2LiAtY86DAtanU7JGYRgtK        5   2    | GALLEN                                  GALLEN                                  
d791330448   |                     Spotify        4VbG7fLmrfYHmCqerZKBes        5   2    | BASS X                                  BASS X                                  
""")
pdbm.pandbLookupSingle()
pdbm.merge(allownew=False, verbose=False)
# Out:
# 00f029ea6a   | 15552                    Spotify        2xMb3TX901tyFs5TPOi1ro                  2    Q BASE                                            Q BASE                                             | 00f029ea6a
# cf0f915700   | 2688                     Spotify        40JYLbI7UkALG8X4IAOjgC                  2    SANTOS                                            SANTOS                                             | cf0f915700
# 2e533da507   | 294098                   Spotify        3RKpqQ3N1VwInnXiOIZcsb                  2    NECROS                                            NECROS                                             | 2e533da507
# 97fc3dea43   | 37315                    Spotify        2LiAtY86DAtanU7JGYRgtK                  2    GALLEN                                            GALLEN                                             | 97fc3dea43
# d791330448   | 48442                    Spotify        4VbG7fLmrfYHmCqerZKBes                  2    BASS X                                            BASS X                                             | d791330448
#   ==> Found [5] Matches For [5] [Discogs] IDs From [1] DBs
#   ==> Getting Master ID Lookup
#   ==> Found [5] Known Matches
#   ==> Found [0] Multi Matches
#   ==> Found [0] New Matches
#   ==> Added [5] Known Matches
# Saving Master DataFrame To /Users/tgadfort/opt/anaconda3/envs/py310/pandb/musicdb/manualEntries.p

# %%
pdbm = PanDBMatch(baseDB, verbose=True)
pdbm.select(minQual=1, maxQual=2, minName=5)
# Out:
# *******************************************************************************************************************************************************************************
# **                                                                             PanDBMatch()                                                                                  **
# *******************************************************************************************************************************************************************************
# 21c148a222   |                     Spotify        4oCpOnsK4LBZ9oQKLUL5WP        5   1    | MANIAC                                  MANIAC
# 673a5c9d06   |                     Spotify        3gk1qtgjN7573QTJca3AqL        5   1    | SHIFTY                                  SHIFTY
# d7a42e60ee   |                     Spotify        4YKydH9LXgJ0DvsLP7DAow        5   1    | CROOKS                                  CROOKS
# 30d2dc4fc1   |                     Spotify        0LRoKEwH2xxfoZRCnWyU9T        5   1    | SHOGUN                                  SHOGUN
# 7f69f5eaf5   |                     Spotify        4d3PE3yuDAjG1qCMqk4Z54        5   1    | DASOUL                                  DASOUL
# 539fb029a4   |                     Spotify        3hrtWqTWO3ZRGYgS7CCAm4        5   1    | UNDERS                                  UNDERS
# 772738c4a4   |                     Spotify        2bOPeIisA5LxbRAC4UJaEx        5   1    | L.A.X.                                  L.A.X.
# 531bc2dda4   |                     Spotify        3AW8a947YyTYwuINbwvX7u        5   1    | QUJILA                                  QUJILA
# b20917b5bf   |                     Spotify        4ykknKGuRFwNHg7gUB2GPD        5   1    | MAVRIK                                  MAVRIK
# 7cd86f791f   |                     Spotify        0s4kDmQVJTr0vKfjMEB4Hl        5   1    | KRUNCH                                  KRUNCH
# 6a7296ecc0   |                     Spotify        1oK0tJAQOXCP48JvYDu96h        5   1    | REFORM                                  REFORM
# 6edc73d627   |                     Spotify        019lYXnA4ZwGYTfkiSxNNI        5   1    | INSANE                                  INSANE
# 563dfaea8a   |                     Spotify        1g4hBnc609oQHqjP6hnI36        5   1    | DARMEC                                  DARMEC
# b5a232e2c4   |                     Spotify        2pYsh3CwHhlw61pHboGJVX        5   1    | MEDUSA                                  MEDUSA
# cd58b1412b   |                     Spotify        4lqxrwkJ16gYkKNumLA3SL        5   1    | U-KNOW                                  U-KNOW
# 960cbbefc7   |                     Spotify        2xQEzjGdoQ5ay5KeZ5jcVL        5   1    | LITTLE                                  LITTLE
# 9449438a17   |                     Spotify        6sirVuFnVaGXKD617P8v6q        5   1    | FUNGUS                                  FUNGUS
# 6d51e41c98   |                     Spotify        316dqb4Ik7CR4xx3GR2cMi        5   1    | DJ 007                                  DJ 007
# ce72fcb22c   |                     Spotify        1u3Sue21yIjfxde6IFiFmi        5   1    | LECTER                                  LECTER
#   ==> Found [19] Matches For [19] [Discogs] IDs From [1] DBs

# %%
pdbm.include("""
21c148a222   |                     Spotify        4oCpOnsK4LBZ9oQKLUL5WP        5   1    | MANIAC                                  MANIAC                                  
673a5c9d06   |                     Spotify        3gk1qtgjN7573QTJca3AqL        5   1    | SHIFTY                                  SHIFTY                                  
d7a42e60ee   |                     Spotify        4YKydH9LXgJ0DvsLP7DAow        5   1    | CROOKS                                  CROOKS                                  
30d2dc4fc1   |                     Spotify        0LRoKEwH2xxfoZRCnWyU9T        5   1    | SHOGUN                                  SHOGUN                                  
7f69f5eaf5   |                     Spotify        4d3PE3yuDAjG1qCMqk4Z54        5   1    | DASOUL                                  DASOUL                                  
539fb029a4   |                     Spotify        3hrtWqTWO3ZRGYgS7CCAm4        5   1    | UNDERS                                  UNDERS                                  
772738c4a4   |                     Spotify        2bOPeIisA5LxbRAC4UJaEx        5   1    | L.A.X.                                  L.A.X.                                  
531bc2dda4   |                     Spotify        3AW8a947YyTYwuINbwvX7u        5   1    | QUJILA                                  QUJILA                                  
b20917b5bf   |                     Spotify        4ykknKGuRFwNHg7gUB2GPD        5   1    | MAVRIK                                  MAVRIK                                  
7cd86f791f   |                     Spotify        0s4kDmQVJTr0vKfjMEB4Hl        5   1    | KRUNCH                                  KRUNCH                                  
6a7296ecc0   |                     Spotify        1oK0tJAQOXCP48JvYDu96h        5   1    | REFORM                                  REFORM                                  
6edc73d627   |                     Spotify        019lYXnA4ZwGYTfkiSxNNI        5   1    | INSANE                                  INSANE                                  
563dfaea8a   |                     Spotify        1g4hBnc609oQHqjP6hnI36        5   1    | DARMEC                                  DARMEC                                  
b5a232e2c4   |                     Spotify        2pYsh3CwHhlw61pHboGJVX        5   1    | MEDUSA                                  MEDUSA                                  
cd58b1412b   |                     Spotify        4lqxrwkJ16gYkKNumLA3SL        5   1    | U-KNOW                                  U-KNOW                                  
960cbbefc7   |                     Spotify        2xQEzjGdoQ5ay5KeZ5jcVL        5   1    | LITTLE                                  LITTLE                                  
9449438a17   |                     Spotify        6sirVuFnVaGXKD617P8v6q        5   1    | FUNGUS                                  FUNGUS                                  
6d51e41c98   |                     Spotify        316dqb4Ik7CR4xx3GR2cMi        5   1    | DJ 007                                  DJ 007                                  
ce72fcb22c   |                     Spotify        1u3Sue21yIjfxde6IFiFmi        5   1    | LECTER                                  LECTER                                  
""")
pdbm.pandbLookupSingle()
pdbm.merge(allownew=False, verbose=False)
# Out:
# 21c148a222   | 1077177                  Spotify        4oCpOnsK4LBZ9oQKLUL5WP                  1    MANIAC                                            MANIAC                                             | 21c148a222
# 673a5c9d06   | 14452                    Spotify        3gk1qtgjN7573QTJca3AqL                  1    SHIFTY                                            SHIFTY                                             | 673a5c9d06
# d7a42e60ee   | 1662793                  Spotify        4YKydH9LXgJ0DvsLP7DAow                  1    CROOKS                                            CROOKS                                             | d7a42e60ee
# 30d2dc4fc1   | 1703325                  Spotify        0LRoKEwH2xxfoZRCnWyU9T                  1    SHOGUN                                            SHOGUN                                             | 30d2dc4fc1
# 7f69f5eaf5   | 1819320                  Spotify        4d3PE3yuDAjG1qCMqk4Z54                  1    DASOUL                                            DASOUL                                             | 7f69f5eaf5
# 539fb029a4   | 1861319                  Spotify        3hrtWqTWO3ZRGYgS7CCAm4                  1    UNDERS                                            UNDERS                                             | 539fb029a4
# 772738c4a4   | 187097                   Spotify        2bOPeIisA5LxbRAC4UJaEx                  1    L.A.X.                                            L.A.X.                                             | 772738c4a4
# 531bc2dda4   | 1976040                  Spotify        3AW8a947YyTYwuINbwvX7u                  1    QUJILA                                            QUJILA                                             | 531bc2dda4
# b20917b5bf   | 2428321                  Spotify        4ykknKGuRFwNHg7gUB2GPD                  1    MAVRIK                                            MAVRIK                                             | b20917b5bf
# 7cd86f791f   | 243878                   Spotify        0s4kDmQVJTr0vKfjMEB4Hl                  1    KRUNCH                                            KRUNCH                                             | 7cd86f791f
# 6a7296ecc0   | 284343                   Spotify        1oK0tJAQOXCP48JvYDu96h                  1    REFORM                                            REFORM                                             | 6a7296ecc0
# 6edc73d627   | 2965693                  Spotify        019lYXnA4ZwGYTfkiSxNNI                  1    INSANE                                            INSANE                                             | 6edc73d627
# 563dfaea8a   | 2967531                  Spotify        1g4hBnc609oQHqjP6hnI36                  1    DARMEC                                            DARMEC                                             | 563dfaea8a
# b5a232e2c4   | 31553                    Spotify        2pYsh3CwHhlw61pHboGJVX                  1    MEDUSA                                            MEDUSA                                             | b5a232e2c4
# cd58b1412b   | 4367073                  Spotify        4lqxrwkJ16gYkKNumLA3SL                  1    U-KNOW                                            U-KNOW                                             | cd58b1412b
# 960cbbefc7   | 694754                   Spotify        2xQEzjGdoQ5ay5KeZ5jcVL                  1    LITTLE                                            LITTLE                                             | 960cbbefc7
# 9449438a17   | 752290                   Spotify        6sirVuFnVaGXKD617P8v6q                  1    FUNGUS                                            FUNGUS                                             | 9449438a17
# 6d51e41c98   | 824669                   Spotify        316dqb4Ik7CR4xx3GR2cMi                  1    DJ 007                                            DJ 007                                             | 6d51e41c98
# ce72fcb22c   | 968768                   Spotify        1u3Sue21yIjfxde6IFiFmi                  1    LECTER                                            LECTER                                             | ce72fcb22c
#   ==> Found [19] Matches For [19] [Discogs] IDs From [1] DBs
#   ==> Getting Master ID Lookup
#   ==> Found [19] Known Matches
#   ==> Found [0] Multi Matches
#   ==> Found [0] New Matches
#   ==> Added [19] Known Matches
# Saving Master DataFrame To /Users/tgadfort/opt/anaconda3/envs/py310/pandb/musicdb/manualEntries.p

# %%
pdbm.mergeMultiRows()

# %%
# Fix This:

# %%
#                       ArtistName      Rank Albums Counts
#nnnnnnnnXXX0005700XXX1     NEGOTO  352386.0   60.0    2.0
#ppppppppXXX0000853XXX1       Pace  209804.0   21.0    2.0
#  ==> Set [nnnnnnnnXXX0005700XXX1/MusicBrainz] to [213198891227095180691705052781978185502]
#  ==> Merged [nnnnnnnnXXX0005700XXX1] and [ppppppppXXX0000853XXX1]

#jjjjjjjjXXX0039151XXX1  Jonatan Leandoer127  47615.0  121.0    5.0
#jjjjjjjjXXX0039152XXX1   jonatan leandoer96  66762.0  112.0    5.0
#                         ArtistName     Rank Albums Counts
#ddddddddXXX0005320XXX1    Daniel Band  39093.0  306.0    4.0
#ddddddddXXX0007084XXX1  Daniele Baldi  34377.0  308.0    5.0
#f212b5e651   |                     Beatport       733318              2   5    | THE MOLE                                THE MOLE'S                               | f212b5e651
#4b6775f819   | 71332102510167766955788643552801425220Deezer         4846141                                 1    THE PAINT MOVEMENT                                THE NEXT MOVEMENT                                  | 4b6775f819
#40e2c8793c   | 38311                    Spotify        6fasWkpvAg1x51osk5BWZ9                  1    NINE DAYS WONDER                                  NINE DAYS GONE                                     | 40e2c8793c

# %% [markdown]
# # PanDB

# %%
ts = Timestat("Loading global")
pdbio = PanDB()
mmeDF = pdbio.getData()
ts.stop()

# %%
from master import MasterDBs
dbs = MasterDBs().getDBs()

# %%
#mmeDF[dbs]

# %%
ts = Timestat("Saving db data ~25 sec total")
for db in dbs:
    data = mmeDF[db]
    data = data[data.notna()]
    eval(f"pdbio.save{db}Data(data=data)")
ts.stop()

# %%
from pandas import concat
tmp = []
ts = Timestat("Loading DB Data (~10 sec)")
for db in dbs:
    tmp.append(eval(f"pdbio.get{db}Data()"))
ts.update()
x = concat(tmp, axis=1)
ts.stop()

# %%
x

# %%
mmeDF.head()
