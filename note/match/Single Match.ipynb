# %%
# %load_ext autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100`% !important; }</style>"))
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
# Out:
# <style>.container { width:100`% !important; }</style>

# %%
from match import SingleMatchDB, SingleCrossMatchDB, PanDBMatch, MatchReq, NameReq, AlbumReq, MatchDBDataIO
from master import MasterMetas, MusicDBPermDir, MasterDBs
from ioutils import FileIO
io = FileIO()

# %%
minL = 5
maxL = 6

minA = 1
maxA = 25

dbs=['Discogs', 'Spotify', 'LastFM', 'Genius', 'RateYourMusic', 'MetalArchives', 'Deezer', 'AllMusic', 'MusicBrainz',
     'AlbumOfTheYear', 'SetListFM', 'Beatport', 'Traxsource', 'MyMixTapez', 'ClassicalArchives']
baseDB    = "RateYourMusic" # Done
baseDB    = "MusicBrainz"
baseDB    = "Discogs"
#compDB    = "LastFM" # Not Done
#compDB    = "Discogs" # Done Done
compDB    = "Beatport" # Done Done Done
compDB    = "Genius" # Done Done Done
compDB    = "AlbumOfTheYear" # Done Done Done
compDB    = "Traxsource" # Done Done Done
compDB    = "MetalArchives" # Done Done Done
compDB    = "Spotify" # Done Done Done
compDB    = "Deezer" # Done Done

baseReq   = {baseDB: MatchReq(NameReq(min=minL, max=maxL), AlbumReq(min=minA, max=maxA))}
compReq   = {compDB: MatchReq(NameReq(min=minL-5, max=maxL+5), AlbumReq(min=3))}

matchReqs  = {**baseReq, **compReq}
mediaTypes = list(MasterMetas().getMedias().values())
reqs       = {"Media": mediaTypes, "ChunkSize": 1000, "Reqs": matchReqs, "Mask": (baseDB,compDB), "NPart": 3, "Match": {"Artist": 0.85, "Medium": 2, "Tight": 1}}


if False:
    baseIO = MatchDBDataIO(db=baseDB, mediaTypes=reqs["Media"], mask=(baseDB,compDB), verbose=True, base=True)
    baseIO.loadNames()
    baseIO.setAvailableNames(reqs["Reqs"][baseDB])

# %%
smdb = SingleMatchDB(baseDB=baseDB, compareDB=compDB, reqs=reqs)
smdb.match()
smdb.save()
del smdb


mdbpd = MusicDBPermDir()
mres  = io.get(mdbpd.getMatchPermPath().join("primaryMatch.p"))
crossreqs  = {"Media": mediaTypes, "Reqs": {baseDB: MatchReq(AlbumReq(min=2))}, "Mask": baseDB, "NPart": 3, "Match": {"Artist": 0.85, "Medium": 2, "Tight": 1}}
scmdb = SingleCrossMatchDB(baseDB, mres, crossreqs, verbose=True)
scmdb.match()
scmdb.save()
del scmdb
# Out:
# *******************************************************************************************************************************************************************************
# **                                                                             SingleMatchDB()                                                                               **
# *******************************************************************************************************************************************************************************
# | ChunkSize ==> 1000
#   MatchDBData(Discogs):
#   MatchDBData(Deezer):
# Process [Matching [Discogs] Against [Deezer]] Start    ==> Time Is 2022-05-23 12:06:52
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# --                                                                             Discogs()                                                                                     --
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#   Process [Loading Discogs Artist Names] Start    ==> Time Is 2022-05-23 12:06:52
#    ==> Loading Names Data
#      ==> Found  610364 Artists Basic Data In Discogs DB
#        ==> Masking Artists
#      ==> Found  792653 Previously Matched Discogs Artists
#      ==> Found  348161 Available Artists In Discogs DB
#      ==> Found  669838 Previously Matched Discogs Artists Without A Deezer Match
#      ==> Found  232989 Available Artists In Discogs DB
#      ==> Cut[Media]           232989 Artists With [2/3430] Min/Max
#      ==> Cut[MediaLen]        147336 Artists With [2/24] Min/Max
#      ==> Cut[Names]           232989 Artists With [0/93] Min/Max
#      ==> Cut[NamesLen]         10737 Artists With [5/5] Min/Max
#      ==> Cut[Final]             7462 Artists With [/] Min/Max
#   Process [Loading Discogs Artist Names] Ran For 26 Seconds    ==> Time Is 2022-05-23 12:07:18
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# --                                                                             Deezer()                                                                                      --
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#   Process [Loading Deezer Artist Names] Start    ==> Time Is 2022-05-23 12:07:18
#    ==> Loading Names Data
#      ==> Found  540356 Artists Basic Data In Deezer DB
#        ==> Masking Artists
#      ==> Found  138699 Previously Cross Matched Artists
#      ==> Found  428274 Artists In Deezer DB
#      ==> Found  428274 Available Artists In Deezer DB
#      ==> Cut[Media]           428274 Artists With [3/589] Min/Max
#      ==> Cut[MediaLen]        428274 Artists With [3/589] Min/Max
#      ==> Cut[Names]           428274 Artists With [1/264] Min/Max
#      ==> Cut[NamesLen]        101906 Artists With [1/10] Min/Max
#      ==> Cut[Final]           101906 Artists With [/] Min/Max
#   Process [Loading Deezer Artist Names] Ran For 6 Seconds    ==> Time Is 2022-05-23 12:07:24
# Splitting Discogs Names Into 7462/1000 ==> 8 Chunks
#
# ...............................................................................................................................................................................
# ..                                                                             Chunk 1/8()                                                                                   ..
# ...............................................................................................................................................................................
#   Process [String Matching 933 [Discogs] x 101906 [Deezer] Artist Names] Start    ==> Time Is 2022-05-23 12:07:24
# 100%|██████████| 311/311 [00:21<00:00, 14.21it/s]
# 100%|██████████| 311/311 [00:22<00:00, 14.10it/s]
# 100%|██████████| 311/311 [00:22<00:00, 13.71it/s]
#   Process [String Matching 933 [Discogs] x 101906 [Deezer] Artist Names] Ran For 47 Seconds    ==> Time Is 2022-05-23 12:08:12
#      ==> Found 933 Name Results
#      ==> Found 605 Artists With One Or More Matches
#      ==> Found 1357 Possible Matches
#     Process [Loading Discogs Media Data] Start    ==> Time Is 2022-05-23 12:08:12
#      ==> Found  610364 Artists Media Data In Discogs DB
#     Process [Loading Discogs Media Data] Ran For 1 Minute and 11 Seconds    ==> Time Is 2022-05-23 12:09:22
#     Process [Loading Deezer Media Data] Start    ==> Time Is 2022-05-23 12:09:22
#      ==> Found    1209 Artists Media Data In Deezer DB
#     Process [Loading Deezer Media Data] Ran For 15 Seconds    ==> Time Is 2022-05-23 12:09:37
#   Process [String Matching 1357 [Discogs] Album Names] Start    ==> Time Is 2022-05-23 12:09:39
#       Process [Matching 1357 Artists' Albums] Start    ==> Time Is 2022-05-23 12:09:39
#       Process [Matching 1357 Artists' Albums] Ran For 9 Seconds    ==> Time Is 2022-05-23 12:09:48
# ==== Match Results ====
# Pure     99
# Great    34
# Sole     20
# Poor      8
# Near      5
# Good      2
# Loose     1
# Low       1
# Name: MediaQuality, dtype: int64
# ==== Match Results ====
# Pure     99
# Great    34
# Sole     20
# Poor      8
# Near      5
# Good      2
# Loose     1
# Low       1
# Name: MediaQuality, dtype: int64
#   Process [String Matching 1357 [Discogs] Album Names] Ran For 15 Seconds    ==> Time Is 2022-05-23 12:09:54
#
# ...............................................................................................................................................................................
# ..                                                                             Chunk 2/8()                                                                                   ..
# ...............................................................................................................................................................................
#   Process [String Matching 933 [Discogs] x 101906 [Deezer] Artist Names] Start    ==> Time Is 2022-05-23 12:09:54
#  75%|███████▌  | 234/311 [00:16<00:05, 14.97it/s]

# %%
pdbm = PanDBMatch(baseDB, verbose=True)
pdbm.select(minQual=5)
pdbm.pandbLookupSingle()
pdbm.merge(allownew=False, verbose=False)

# %%
#pdbm.mergeMultiRows()

# %%
pdbm = PanDBMatch(baseDB, verbose=True)
pdbm.select(minQual=4, maxQual=5, minName=4)

# %%
pdbm.include("""
cc2e1481fc   |                     Deezer         187142              5   4    | HIXXY                                   HIXXY
8a73fef261   |                     Deezer         1728811             5   4    | QYGEN                                   QYGEN
35898e57b3   |                     Deezer         75361222            5   4    | DANTE                                   DANTE
782da48d9d   |                     Deezer         84332               5   4    | DEFAO                                   DEFAO
cc4535fe29   |                     Deezer         86230822            5   4    | BARAK                                   BARAK
8b8bee4b28   |                     Deezer         289421              5   4    | JENNA                                   JENNA
610b022a56   |                     Deezer         176857              5   4    | GORGE                                   GORGE
04aebb1957   |                     Deezer         62389               5   4    | FLORE                                   FLORE
9338311276   |                     Deezer         71759202            5   4    | CYNIC                                   CYNIC
af05845e19   |                     Deezer         4128                5   4    | KÍLA                                   KÍLA
8e5e6a6c07   |                     Deezer         4799776             5   4    | MAPPA                                   MAPPA
821f7a60ef   |                     Deezer         545198              5   4    | CLICK                                   CLICK
1fcb14d998   |                     Deezer         91823               5   4    | BASIC                                   BASIC
de7c871f29   |                     Deezer         1214346             5   4    | ALVAR                                   ALVAR
0b52d8161e   |                     Deezer         10702331            5   4    | BETEO                                   BETEO
98f5eddf21   |                     Deezer         87989052            5   4    | QUARK                                   QUARK
75ae809a13   |                     Deezer         519312              5   4    | BATUK                                   BATUK
18b80f83ec   |                     Deezer         6796417             5   4    | NOSFE                                   NOSFE
""")
pdbm.pandbLookupSingle()
pdbm.merge(allownew=False, verbose=False)
# Out:
# c49d492c1a   | 14138               Deezer         613854              5   4    | ASCEND                                  ASCEND
# 58c8fa5ca4   | 2286414             Deezer         1041041             5   4    | TM EYE                                  TM EYE
# 35f4bf0848   | 2587674             Deezer         1474862             5   4    | KOKOON                                  KOKOON
# baaf5370e4   | 2626423             Deezer         1053359             5   4    | HARROW                                  HARROW
# 404d2d823f   | 26606               Deezer         95252462            5   4    | W-MOON                                  W-MOON
# 610d5f0ce4   | 3127702             Deezer         1488991             5   4    | GOUDIE                                  GOUDIE
# fee1ed147f   | 3768737             Deezer         293567              5   4    | PASTOR                                  PASTOR
# 3c9e31b8ef   | 3917591             Deezer         366499              5   4    | WOMNAL                                  WOMNAL
# 963a3dfdbf   | 4175537             Deezer         68016022            5   4    | OROCHI                                  OROCHI
# 47c62c8944   | 4575840             Deezer         4666254             5   4    | MENARA                                  MENARA
# e8a3c3348f   | 5162801             Deezer         4361718             5   4    | RESINA                                  RESINA
# e8c7553f46   | 610966              Deezer         1590206             5   4    | DJ TAL                                  DJ TAL
# 80fb9cae2d   | 6225646             Deezer         12637131            5   4    | UNDFND                                  UNDFND
# e358ec47cf   | 748154              Deezer         140423              5   4    | VEAGAZ                                  VEAGAZ
#   ==> Found [14] Matches For [14] [Discogs] IDs From [1] DBs
#   ==> Getting Master ID Lookup
#   ==> Found [14] Known Matches
#   ==> Found [0] Multi Matches
#   ==> Found [0] New Matches
#   ==> Added [14] Known Matches
# Saving Master DataFrame To /Users/tgadfort/opt/anaconda3/envs/py310/pandb/musicdb/manualEntries.p

# %%
pdbm.mergeMultiRows()

# %%
pdbm = PanDBMatch(baseDB, verbose=True)
pdbm.select(minQual=2, maxQual=4, minName=4)

# %%
pdbm.include("""
c679f46daa   |                     Deezer         982020              5   2    | SOFALOFA                                SOFALOFA
abedeaefe9   |                     Deezer         7801094             5   2    | MONIKERS                                MONIKERS
f3b279ead0   |                     Deezer         94462               5   3    | BOB ROWE                                BOB ROWE
4917e202ea   |                     Deezer         5040566             5   3    | SECURITY                                SECURITY
9b208584e5   |                     Deezer         1308393             5   2    | PTERADON                                PTERADON
52810efdaf   |                     Deezer         5901313             5   2    | KOLISHIN                                KOLISHIN
bc05bc5c40   |                     Deezer         5610297             5   2    | OH HONEY                                OH HONEY
a0fcb5b358   |                     Deezer         5310714             5   3    | SICKNESS                                SICKNESS
1f6d67a8ee   |                     Deezer         7680158             5   2    | SUPA FLY                                SUPA FLY
57a3d69781   |                     Deezer         11668995            5   2    | SAM GOKU                                SAM GOKU
""")
pdbm.pandbLookupSingle()
pdbm.merge(allownew=False, verbose=False)

# %%
pdbm = PanDBMatch(baseDB, verbose=True)
pdbm.select(minQual=1, maxQual=2, minName=5)

# %%
pdbm.include("""
61f787a497   |                     Deezer         1350904             5   1    | SPOTLESS                                SPOTLESS
cbdaea3d7f   |                     Deezer         153613              5   1    | PORK PIE                                PORK PIE
55de3a8ba7   |                     Deezer         537448              5   1    | ELIAS JR                                ELIAS JR
72947abb1d   |                     Deezer         361065              5   1    | GEOGLYPH                                GEOGLYPH
aa2985e4a7   |                     Deezer         127814              5   1    | TALIESYN                                TALIESYN
e1b8cc9daa   |                     Deezer         84705               5   1    | JANE DYT                                JANE DYT
e04b5300b3   |                     Deezer         1328660             5   1    | CANTICUM                                CANTICUM
3866e5182e   |                     Deezer         4085916             5   1    | FLEX COP                                FLEX COP
3626d6f05a   |                     Deezer         826506              5   1    | RAY CHEN                                RAY CHEN
83bc5f9665   |                     Deezer         6868963             5   1    | G SUDDEN                                G SUDDEN
c5f4c4052c   |                     Deezer         50578382            5   1    | MURA OKA                                MURA OKA
bbf0571d26   |                     Deezer         11341422            5   1    | FUNKTURM                                FUNKTURM
29de8693d1   |                     Deezer         540630              5   1    | 7 ZUMA 7                                7 ZUMA 7
b820120c5b   |                     Deezer         10573479            5   1    | DJ HARAM                                DJ HARAM
bc1947e785   |                     Deezer         5368393             5   1    | AUTENTIC                                AUTENTIC
94d6beb20c   |                     Deezer         12312742            5   1    | DAI KAHT                                DAI KAHT
8be14abf66   |                     Deezer         58823682            5   1    | ZELDE743                                ZELDE743
e2fa43a3f2   |                     Deezer         8804518             5   1    | ICE PACK                                ICE PACK
85ee5be69a   |                     Deezer         139229              5   1    | MENOOSHA                                MENOOSHA
""")
pdbm.pandbLookupSingle()
pdbm.merge(allownew=False, verbose=False)

# %%
pdbm.mergeMultiRows()

# %%
# Fix This:

# %%
#                        ArtistName      Rank Albums Counts
#mmmmmmmmXXX0023381XXX1     Mashina  110557.0  150.0    3.0
#ffffffffXXX0020491XXX1  From Sleep  111372.0  132.0    2.0
#                        ArtistName      Rank Albums Counts
#ccccccccXXX0034347XXX02     Corpus   36782.0  990.0    6.0
#zzzzzzzzXXX0003942XXX1    Zuriaake  256020.0   27.0    3.0
#  ==> Set [ccccccccXXX0034347XXX02/AlbumOfTheYear] to [60793]
#  ==> Set [ccccccccXXX0034347XXX02/Genius] to [369892]
#  ==> Merged [ccccccccXXX0034347XXX02] and [zzzzzzzzXXX0003942XXX1]
#  ==> Dropped Row [zzzzzzzzXXX0003942XXX1]
#                               ArtistName      Rank Albums Counts
#ccccccccXXX0003600XXX1            Capture   81823.0   55.0    6.0
#ccccccccXXX0003601XXX1  Capture The Crown  483661.0   12.0    3.0
#                       ArtistName      Rank Albums Counts
#nnnnnnnnXXX0005700XXX1     NEGOTO  352386.0   60.0    2.0
#ppppppppXXX0000853XXX1       Pace  209804.0   21.0    2.0
#  ==> Set [nnnnnnnnXXX0005700XXX1/MusicBrainz] to [213198891227095180691705052781978185502]
#  ==> Merged [nnnnnnnnXXX0005700XXX1] and [ppppppppXXX0000853XXX1]

#jjjjjjjjXXX0039151XXX1  Jonatan Leandoer127  47615.0  121.0    5.0
#jjjjjjjjXXX0039152XXX1   jonatan leandoer96  66762.0  112.0    5.0
#                         ArtistName     Rank Albums Counts
#ddddddddXXX0005320XXX1    Daniel Band  39093.0  306.0    4.0
#ddddddddXXX0007084XXX1  Daniele Baldi  34377.0  308.0    5.0
#f212b5e651   |                     Beatport       733318              2   5    | THE MOLE                                THE MOLE'S                               | f212b5e651
#4b6775f819   | 71332102510167766955788643552801425220Deezer         4846141                                 1    THE PAINT MOVEMENT                                THE NEXT MOVEMENT                                  | 4b6775f819
#40e2c8793c   | 38311                    Spotify        6fasWkpvAg1x51osk5BWZ9                  1    NINE DAYS WONDER                                  NINE DAYS GONE                                     | 40e2c8793c

# %% [markdown]
# # PanDB

# %%
ts = Timestat("Loading global")
pdbio = PanDB()
mmeDF = pdbio.getData()
ts.stop()

# %%
from master import MasterDBs
dbs = MasterDBs().getDBs()

# %%
#mmeDF[dbs]

# %%
ts = Timestat("Saving db data ~25 sec total")
for db in dbs:
    data = mmeDF[db]
    data = data[data.notna()]
    eval(f"pdbio.save{db}Data(data=data)")
ts.stop()

# %%
from pandas import concat
tmp = []
ts = Timestat("Loading DB Data (~10 sec)")
for db in dbs:
    tmp.append(eval(f"pdbio.get{db}Data()"))
ts.update()
x = concat(tmp, axis=1)
ts.stop()

# %%
x

# %%
mmeDF.head()
