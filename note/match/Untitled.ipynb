# %%
from dbIOGate import dbIOGate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/j1/syf62l4j46q052mwy0366byh0000gn/T/ipykernel_45100/1886630971.py in <module>
# ----> 1 from dbIOGate import dbIOGate
#
# <frozen zipimport> in load_module(self, fullname)
#
# ~/opt/anaconda3/envs/py310/lib/python3.9/site-packages/dbdata-0.0.1-py3.9.egg/dbIOGate.py in <module>
#       1 from masterParams import masterParams
# ----> 2 from allmusic.dbAllMusicIO import dbAllMusicIO
#       3 from discogs.dbDiscogsIO import dbDiscogsIO
#       4 from spotify.dbSpotifyIO import dbSpotifyIO
#       5 from lastfm.dbLastFMIO import dbLastFMIO
#
# ModuleNotFoundError: No module named 'allmusic'
