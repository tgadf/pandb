# %%
# %load_ext autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# %%
from ioutils import FileIO
from fileutils import DirInfo, FileInfo
from master import MasterParams, MusicDBPermDir
from pandas import Series, DataFrame, concat
from sys import prefix
from listUtils import getFlatList
from musicdb import PanDBIO
mp    = MasterParams(verbose=True)
io    = FileIO()
mdbpd = MusicDBPermDir()

# %%
from lib import jiosaavn
mio   = jiosaavn.MusicDBIO(verbose=False)
webio = jiosaavn.RawWebData()
db    = mio.db
permDBDir = mdbpd.getDBPermPath(db)
print("Saving Perminant {0} DB Data To {1}".format(db, permDBDir.str))

# %%
from utils import PoolIO
pio = PoolIO("JioSaavn")
#pio.parse()
#pio.merge()
pio.meta()
pio.sum()
pio.search()

# %%
from base import MusicDBDir, MusicDBData
permDir = MusicDBDir(permDBDir)
localArtists         = MusicDBData(path=permDir, fname="{0}SearchedForLocalArtists".format(db.lower()))
localArtistsAlbums   = MusicDBData(path=permDir, fname="{0}SearchedForLocalArtistsAlbums".format(db.lower()))
localArtistsSongs    = MusicDBData(path=permDir, fname="{0}SearchedForLocalArtistsSongs".format(db.lower()))
localArtistsBio      = MusicDBData(path=permDir, fname="{0}SearchedForLocalArtistsBio".format(db.lower()))
masterArtists        = MusicDBData(path=permDir, fname="{0}SearchedForMasterArtists".format(db.lower()))
searchArtists        = mio.data.getSearchArtistData()
knownArtists         = mio.data.getSummaryNameData()
errors               = MusicDBData(path=permDir, fname="{0}SearchedForErrors".format(db.lower()))

# %%
def getID(ref):
    retval = ref.split("/")[-1] if isinstance(ref,str) and ref.startswith("/artist/") else None
    return retval

##########################################################################################
# Show Summary
##########################################################################################
print("{0} Search Results".format(db))
errors.save(data={})
print("   Local Artists:          {0}".format(len(localArtists.get())))
print("   Local Artists Albums:   {0}".format(len(localArtistsAlbums.get())))
print("   Local Artists Songs:    {0}".format(len(localArtistsSongs.get())))
print("   Local Artists Bio:      {0}".format(len(localArtistsBio.get())))
print("   Master Artists:         {0}".format(len(masterArtists.get())))
print("   Errors:                 {0}".format(len(errors.get())))
print("   Search Artists:         {0}".format(searchArtists.shape[0]))
print("   Known IDs:              {0}".format(len(knownArtists)))


#   Local Artists:          53505

# %% [markdown]
# # Download Starter Info

# %%
mio   = jiosaavn.MusicDBIO(verbose=False,local=True)
webio = jiosaavn.RawWebData(debug=False)

# %%
from apiutils import WebIO
from ioutils import FileIO, HTMLIO
io = FileIO()
hio = HTMLIO()
wio = WebIO()

# %%
from time import sleep
artists = []
urls = []
urls.append("https://www.jiosaavn.com/featured/trending_today/I3kvhipIy73uCJW60TJk1Q__")
urls.append("https://www.jiosaavn.com/top-artists")
urls.append("https://www.jiosaavn.com/featured/hindi_chartbusters/1HiqW,xnqZTuCJW60TJk1Q__")
urls.append("https://www.jiosaavn.com/featured/romantic_top_40/m9Qkal5S733ufxkxMEIbIw__")
urls.append("https://www.jiosaavn.com/featured/hindi_00s/tsJahdem34A_")
urls.append("https://www.jiosaavn.com/featured/hindi_90s/T64MUCqdndw_")
urls.append("https://www.jiosaavn.com/featured/hindi_80s/fE9YxTvTDjU_")
urls.append("https://www.jiosaavn.com/featured/hindi_70s/VSMrnr-njCk_")
urls.append("https://www.jiosaavn.com/featured/hindi_60s/TOL5Rewc8Mk_")
urls.append("https://www.jiosaavn.com/featured/hindi_retro/dYn-,-QcKzA_")
urls.append("https://www.jiosaavn.com/featured/hindi-edm/OYy8Eam-WpZFo9wdEAzFBA__")
urls.append("https://www.jiosaavn.com/featured/bollywood_folk/CbV0mtrQazQ_")
urls.append("https://www.jiosaavn.com/featured/punjab_se_bollywood/obx07Zza,rHuCJW60TJk1Q__")

urls = []
urls.append("https://www.jiosaavn.com/featured/at_the_box_office/VGYtuNra07Lc1EngHtQQ2g__")
urls.append("https://www.jiosaavn.com/featured/most_searched_songs_-_hindi/csv-SfcHUmHc1EngHtQQ2g__")
urls.append("https://www.jiosaavn.com/featured/jiosaavn_spotted_-_hindi_finalists/iYJ0ItDPgWVkVFjX2wgHNA__")
urls.append("https://www.jiosaavn.com/featured/surprise_me/1ZOczFTRyFw_")
urls.append("https://www.jiosaavn.com/featured/2_in_tune_-_lata_and_kishore/p5z5SrxJRY4_")
urls.append("https://www.jiosaavn.com/featured/leading_ladies_-_kangana_ranaut/fvtptx-b3e4_")
urls.append("https://www.jiosaavn.com/featured/2000s-duets---hindi/NaV3HkhAB5FFo9wdEAzFBA__")
urls.append("https://www.jiosaavn.com/featured/taaza-tunes/Me5RridRfDk_")
urls.append("https://www.jiosaavn.com/featured/nach-le/UQjTO6rFZfc_")
urls.append("https://www.jiosaavn.com/featured/ishqiyaan/dyqSeSlJrvI_")
urls.append("https://www.jiosaavn.com/featured/90s-duets---hindi/Icd5-BIRMLpFo9wdEAzFBA__")
urls.append("https://www.jiosaavn.com/featured/all-arijit/Iz0pi7nkjUE_")
urls.append("https://www.jiosaavn.com/featured/lyrically-mast/BWNIAJIwMPkwkg5tVhI3fw__")

urls = []
urls.append("https://www.jiosaavn.com/featured/punjabi-chartbusters/wbSW,qO528wGSw2I1RxdhQ__")
urls.append("https://www.jiosaavn.com/featured/punjabi-workout/1lv8piStXj4_")
urls.append("https://www.jiosaavn.com/featured/now-trending---punjabi/Vy34km3okmQ_")
urls.append("https://www.jiosaavn.com/featured/punjabi-top-songs/W6DUe-fP3X8_")
urls.append("https://www.jiosaavn.com/featured/charts_2010s/1YEQu,ZfmLDuCJW60TJk1Q__")
urls.append("https://www.jiosaavn.com/featured/kannada_chartbusters/wbSW,qO528xieSJqt9HmOQ__")
urls.append("https://www.jiosaavn.com/featured/telugu_chartbusters/1HiqW,xnqZRFo9wdEAzFBA__")
urls.append("https://www.jiosaavn.com/featured/malayalam_chartbusters/wbSW,qO528zufxkxMEIbIw__")
urls.append("https://www.jiosaavn.com/featured/odia_chartbusters/wzBigaZ0A28_")
urls.append("https://www.jiosaavn.com/featured/gujarati_chartbusters/wbSW,qO528wwkg5tVhI3fw__")
urls.append("https://www.jiosaavn.com/featured/marathi_chartbusters/1HiqW,xnqZSO0eMLZZxqsA__")
urls.append("https://www.jiosaavn.com/featured/bhojpuri_chartbusters/slbY3IGmXNc_")
urls.append("https://www.jiosaavn.com/featured/tamil_chartbusters/1HiqW,xnqZRieSJqt9HmOQ__")
for url in urls:
    retval = wio.get(url)
    bsdata = hio.get(retval.data)
    for ref in bsdata.findAll("a"):
        href = ref.get('href')
        if isinstance(href,str) and "/artist/" in href:
            title = ref.get('title')
            text  = ref.get('text')
            if isinstance(title, str):
                name = title
            elif isinstance(text, str):
                name = text
            else:
                name = ref.text
            artists.append({"Name": name, "Ref": href})
    sleep(5)

# %%
from pandas import DataFrame, merge
df = DataFrame(artists)
vc = df["Ref"].value_counts()
df = merge(df.drop_duplicates(), DataFrame(vc).reset_index().rename(columns={"index": "Ref", "Ref": "Num"}), on="Ref").sort_values(by="Num", ascending=False)
df = df[~df["Name"].isin(["More", "Artist Albums", "Artist Songs", "Log In", "Artist Biography", "Artist Overview", "Sign Up"])]
df.index = df["Ref"].apply(getID)
df = df[df.index.map(len) > 0]
df.index.name = ""

# %%
from pandas import DataFrame, merge
df = DataFrame(artists)
vc = df["Ref"].value_counts()
starter = merge(df.drop_duplicates(), DataFrame(vc).reset_index().rename(columns={"index": "Ref", "Ref": "Num"}), on="Ref").sort_values(by="Num", ascending=False)

# %%
io.save(idata=starter, ifile="starter.p")

# %% [markdown]
# # Download Artist Data

# %%
mio   = jiosaavn.MusicDBIO(verbose=False,local=True,mkDirs=False)
webio = jiosaavn.RawWebData(debug=False)

# %%
useSearchData  = True
useStarterData = False

if useStarterData is True:
    artistNames       = io.get("starter.p")
    artistNames.index = artistNames["Ref"].apply(getID)
    localArtistsDict  = localArtists.get()
    artistNamesToGet  = artistNames[~artistNames.index.isin(localArtistsDict.keys())]
elif useSearchData is True:
    artistNames      = searchArtists.sort_values(by="Num", ascending=False)
    localArtistsDict = localArtists.get()
    searchedForErrors = errors.get()
    artistNamesToGet = artistNames[(~artistNames.index.isin(localArtistsDict.keys())) & (~artistNames.index.isin(searchedForErrors.keys()))]

print("# {0} Search Results".format(db))
print("#   Available Names:      {0}".format(len(artistNames)))
print("#   Known Artist Names:   {0}".format(len(localArtistsDict)))
print("#   Artist Names To Get:  {0}".format(len(artistNamesToGet)))

#   Artist Names To Get:  5745

# %%
#artistNames.index.map(mio.getModVal)

# %%
from timeutils import Timestat, TermTime

ts = Timestat("Getting {0} ArtistIDs".format(db))
#tt = TermTime("tomorrow", "10:50am")
tt = TermTime("today", "11:00am")
maxN = 50000000

n  = 0
localArtistsDict  = localArtists.get()
searchedForErrors = errors.get()

for i,(artistID,row) in enumerate(artistNamesToGet.iterrows()):
    artistName = row["Name"]
    artistURL  = row["Ref"]
    if localArtistsDict.get(artistID) is not None:
        continue
    if searchedForErrors.get(artistID) is not None:
        continue
                
    response = webio.getArtistData(artistName=artistName, artistURL=artistURL)
    if response is None or len(response) == 0:
        print("Error ==> {0}".format((artistID,artistName)))
        searchedForErrors[artistID] = artistName
        errors.save(data=searchedForErrors)
        webio.sleep(5)
        continue
        
    mio.data.saveRawData(data=response, modval=mio.getModVal(artistID), dbID=artistID)
    localArtistsDict[artistID] = artistName
    webio.sleep(5.0)
    n += 1
        
    if n % 25 == 0:
        print("="*150)
        ts.update(n=n)
        print("Saving {0} {1} Artists Data".format(len(localArtistsDict), db))
        localArtists.save(data=localArtistsDict)
        print("="*150)
        webio.wait(5.0)
        if tt.isFinished():
            break
    
ts.stop()
print("Saving {0} {1} Artists Data".format(len(localArtistsDict), db))
localArtists.save(data=localArtistsDict)
if len(searchedForErrors) > 0:
    print("Saving {0} {1} Errors".format(len(searchedForErrors), db))
    errors.save(data=searchedForErrors)

# %%
del searchedForErrors['4r12ovjmDRk_']
errors.save(data=searchedForErrors)

# %%
localArtists.save(data=localArtistsDict)

# %%
from lib.jiosaavn import moveLocalFiles
moveLocalFiles()

# %%
/Volumes/Piggy/Discog/artists-jiosaavn/0/album/ER4rjfcA3d8_.p
/Volumes/Piggy/Discog/artists-jiosaavn/0/song/4yQ-l5YZhLk_.p

# %%
mio   = jiosaavn.MusicDBIO(verbose=False)
for modVal in range(59,100):
    #print(modVal)
    mio.prd.parse(modVal)

# %%
from fileutils import FileInfo
files = """
/Volumes/Piggy/Discog/artists-jiosaavn/4/album/PdGln1yqWas_.p
/Volumes/Piggy/Discog/artists-jiosaavn/6/album/bSVboQTSzYo_.p
/Volumes/Piggy/Discog/artists-jiosaavn/6/album/zlan5NWU-,E_.p
/Volumes/Piggy/Discog/artists-jiosaavn/6/song/I6b9vhZFsxw_.p
206/589: /Volumes/Piggy/Discog/artists-jiosaavn/6/song/bSVboQTSzYo_.p
181/654: /Volumes/Piggy/Discog/artists-jiosaavn/7/album/Clw,0GZldQ8_.p
136/654: /Volumes/Piggy/Discog/artists-jiosaavn/7/song/plgkKgJCLe4_.p
15/653: /Volumes/Piggy/Discog/artists-jiosaavn/8/album/BFnl8PgKLDk_.p
152/680: /Volumes/Piggy/Discog/artists-jiosaavn/9/album/KgTXuDilBnM_.p
443/673: /Volumes/Piggy/Discog/artists-jiosaavn/11/album/DamDtUbIX1k_.p
44/673: /Volumes/Piggy/Discog/artists-jiosaavn/11/song/z,hNHv1c1EY_.p
145/715: /Volumes/Piggy/Discog/artists-jiosaavn/12/album/Bdq8POhbk5w_.p
292/714: /Volumes/Piggy/Discog/artists-jiosaavn/12/album/80TENIsYR,Q_.p
432/713: /Volumes/Piggy/Discog/artists-jiosaavn/12/album/iALkWjokyCs_.p
518/685: /Volumes/Piggy/Discog/artists-jiosaavn/13/album/NjhsHr,BOZ0_.p
22/675: /Volumes/Piggy/Discog/artists-jiosaavn/14/song/r7lhLaRxNa8_.p
276/654: /Volumes/Piggy/Discog/artists-jiosaavn/16/album/g5JsqVElCas_.p
276/654: /Volumes/Piggy/Discog/artists-jiosaavn/16/song/g5JsqVElCas_.p
186/647: /Volumes/Piggy/Discog/artists-jiosaavn/18/album/TTmx1cOX69c_.p
222/644: /Volumes/Piggy/Discog/artists-jiosaavn/20/song/5lthUoFU2hM_.p
486/643: /Volumes/Piggy/Discog/artists-jiosaavn/20/song/uGe-fOLbSQ4_.p
501/640: /Volumes/Piggy/Discog/artists-jiosaavn/21/album/exF36Yj,Fyk_.p
501/640: /Volumes/Piggy/Discog/artists-jiosaavn/21/song/exF36Yj,Fyk_.p
422/660: /Volumes/Piggy/Discog/artists-jiosaavn/24/album/s1UjkRihuMI_.p
.p
[/Volumes/Piggy/Discog/artists-jiosaavn/94/album/mXEgj1NGAKo_.p]
/Volumes/Piggy/Discog/artists-jiosaavn/94/album/mXEgj1NGAKo_.p
/Volumes/Piggy/Discog/artists-jiosaavn/94/song/xiygdAKBgDc_.p
/Volumes/Piggy/Discog/artists-jiosaavn/94/song/cnolGTsii1Q_.p
/Volumes/Piggy/Discog/artists-jiosaavn/94/song/tWh1BO,Dt9k_.p
/Volumes/Piggy/Discog/artists-jiosaavn/94/song/KBlELJp-FHQ_.p
/Volumes/Piggy/Discog/artists-jiosaavn/94/song/HuDDa2ZddjM_.p
/Volumes/Piggy/Discog/artists-jiosaavn/94/song/hZ2NVBXHoUo_.p
/Volumes/Piggy/Discog/artists-jiosaavn/95/album/UjTijgL59RU_.p
/Volumes/Piggy/Discog/artists-jiosaavn/95/album/YhTvuZN89R0_.p
/Volumes/Piggy/Discog/artists-jiosaavn/95/album/4pZwEo2z1iU_.p
/Volumes/Piggy/Discog/artists-jiosaavn/95/song/k6RFMnOizFQ_.p
/Volumes/Piggy/Discog/artists-jiosaavn/95/song/e-WPOehauM0_.p
/Volumes/Piggy/Discog/artists-jiosaavn/95/song/3F5XkGHAjHY_.p
[/Volumes/Piggy/Discog/artists-jiosaavn/95/song/AOuX4IYoGlw_.p]
/Volumes/Piggy/Discog/artists-jiosaavn/95/song/AOuX4IYoGlw_.p
/Volumes/Piggy/Discog/artists-jiosaavn/95/song/BskMwucb-Ho_.p
/Volumes/Piggy/Discog/artists-jiosaavn/96/album/e2w,bCU9sjI_.p
[/Volumes/Piggy/Discog/artists-jiosaavn/96/album/MHiaEJbZVms_.p]
/Volumes/Piggy/Discog/artists-jiosaavn/96/album/MHiaEJbZVms_.p
[/Volumes/Piggy/Discog/artists-jiosaavn/96/album/oFsRUs6qpHw_.p]
/Volumes/Piggy/Discog/artists-jiosaavn/96/album/oFsRUs6qpHw_.p
/Volumes/Piggy/Discog/artists-jiosaavn/96/album/99fPBnWO12c_.p
/Volumes/Piggy/Discog/artists-jiosaavn/96/album/l77j19uNpmY_.p
/Volumes/Piggy/Discog/artists-jiosaavn/96/album/uNxeG9MjrAI_.p
[/Volumes/Piggy/Discog/artists-jiosaavn/96/song/oFsRUs6qpHw_.p]
/Volumes/Piggy/Discog/artists-jiosaavn/96/song/oFsRUs6qpHw_.p
/Volumes/Piggy/Discog/artists-jiosaavn/96/song/a9A2KMUy8lk_.p
/Volumes/Piggy/Discog/artists-jiosaavn/96/song/9szOlor9yXM_.p
/Volumes/Piggy/Discog/artists-jiosaavn/97/album/C5nS9TLvV,c_.p
/Volumes/Piggy/Discog/artists-jiosaavn/97/album/i10eTa6O,SE_.p
[/Volumes/Piggy/Discog/artists-jiosaavn/97/album/PIjGJpwQdeQ_.p]
/Volumes/Piggy/Discog/artists-jiosaavn/97/album/PIjGJpwQdeQ_.p
/Volumes/Piggy/Discog/artists-jiosaavn/97/album/HzxvxdzCZ9w_.p
/Volumes/Piggy/Discog/artists-jiosaavn/97/song/03U3dIFIPuo_.p
/Volumes/Piggy/Discog/artists-jiosaavn/98/album/T2f2E,puRjc_.p
/Volumes/Piggy/Discog/artists-jiosaavn/98/song/NZhFDY3fLy8_.p
/Volumes/Piggy/Discog/artists-jiosaavn/98/song/ntFEd3xZliw_.p
/Volumes/Piggy/Discog/artists-jiosaavn/98/song/GuAKKSc6ThI_.p
/Volumes/Piggy/Discog/artists-jiosaavn/99/album/L6aZEGVPZyI_.p
/Volumes/Piggy/Discog/artists-jiosaavn/99/album/SmnQideCEwI_.p
/Volumes/Piggy/Discog/artists-jiosaavn/99/album/fCbSLkOHEsI_.p
/Volumes/Piggy/Discog/artists-jiosaavn/99/song/gEpnVSyAcWU_.p
""".split("\n")
for ifile in files:
    break
    if len(ifile) > 0:
        FileInfo(ifile.split()[-1]).rmFile()

# %%
missingIDFiles = [ifile.split()[-1] for ifile in files if len(ifile) > 0]

# %%
songIDs  = {}
albumIDs = {}
for ifile in missingIDFiles:
    artistID = FileInfo(ifile).basename
    if "/song/" in ifile:
        songIDs[artistID] = ifile
    elif "/album/" in ifile:
        albumIDs[artistID] = ifile
    else:
        raise ValueError("What?")

# %%
localArtistsAlbumsData = localArtistsAlbums.get()
for artistID in albumIDs:
    del localArtistsAlbumsData[artistID]
localArtistsAlbums.save(data=localArtistsAlbumsData)

localArtistsSongsData  = localArtistsSongs.get()
for artistID in songIDs:
    del localArtistsSongsData[artistID]
localArtistsSongs.save(data=localArtistsSongsData)

# %%
from utils import PoolIO
pio = PoolIO("JioSaavn")
pio.parse()
pio.merge()
pio.meta()
pio.sum()
pio.search()

# %%
files = mio.dir.getRawAlbumModValDataDir(0).glob("*.p")

# %%
rdb = RawDBData()
for ifile in files:
    print(ifile)
    retval = rdb.getAlbumData(ifile)

# %%
rdb.getBasicData()

# %%
rdb.artistMedia

# %% [markdown]
# # Create Tabs Data

# %%
mio   = jiosaavn.MusicDBIO(verbose=False)
createTabs = True
if createTabs is True:
    def getURLs(rData):
        extraData = rData.profile.extra
        retval = extraData.get("Tabs", {}) if isinstance(extraData, dict) else {}
        return retval

    tabURLs = []
    from pandas import Series
    for modVal in range(100):
        tabs = mio.data.getModValData(modVal).apply(getURLs)
        tabURLs.append(tabs)
        
    tabsData = concat(tabURLs)    
    df = DataFrame(mio.data.getSummaryNameData()).join(mio.data.getSummaryNumAlbumsData()).join(tabsData.apply(Series))
    io.save(idata=df, ifile="tabs.p")

# %% [markdown]
# # Download Artist Albums Data

# %%
mio   = jiosaavn.MusicDBIO(verbose=False,local=True,mkDirs=False)
webio = jiosaavn.RawWebData(debug=False)

# %%
useCountsData = True
if useCountsData is True:
    artistNames = io.get('tabs.p').sort_values(by="NumAlbums", ascending=False).reset_index()
    artistNames.index = artistNames["Album"].map(getID)
    artistNames.index.name = ""
    localArtistsAlbumsData = localArtistsAlbums.get()
    artistNamesToGet = artistNames[~artistNames.index.isin(localArtistsAlbumsData.keys())][["Name", "Album"]]

print("# {0} Search Results".format(db))
print("#   Available Names:      {0}".format(len(artistNames)))
print("#   Known Artist Names:   {0}".format(len(localArtistsAlbumsData)))
print("#   Artist Names To Get:  {0}".format(len(artistNamesToGet)))

#   Artist Names To Get:  20822
#   Artist Names To Get:  15022

# %%
from timeutils import Timestat, TermTime

ts = Timestat("Getting {0} ArtistIDs".format(db))
tt = TermTime("tomorrow", "9:50am")
#tt = TermTime("today", "10:00pm")
maxN = 50000000

n  = 0
localArtistsAlbumsData = localArtistsAlbums.get()
searchedForErrors = errors.get()

for i,(artistID,row) in enumerate(artistNamesToGet.iterrows()):
    artistName      = row["Name"]
    artistAlbumURL  = row["Album"]
    #artistSongURL   = row["Song"]
    #artistBioURL    = row["Bio"]
    if localArtistsAlbumsData.get(artistID) is not None:
        continue
    #if searchedForErrors.get(artistID) is not None:
    #    continue

    response = webio.getArtistData(artistName=artistName, artistURL=artistAlbumURL)
    if response is None or len(response) == 0:
        print("Error ==> {0}".format((artistID,artistName)))
        searchedForErrors[artistID] = artistName
        errors.save(data=searchedForErrors)
        webio.sleep(5)
        continue
        
    mio.data.saveRawArtistAlbumData(data=response, modval=mio.getModVal(artistID), dbID=artistID)
    localArtistsAlbumsData[artistID] = artistName
    webio.sleep(5.0)
    n += 1
        
    if n % 25 == 0:
        print("="*150)
        ts.update(n=n)
        print("Saving {0} {1} Artists Data".format(len(localArtistsAlbumsData), db))
        localArtistsAlbums.save(data=localArtistsAlbumsData)
        print("="*150)
        webio.wait(5.0)
        if tt.isFinished():
            break
    
if True:
    ts.stop()
    print("Saving {0} {1} Artists Data".format(len(localArtistsAlbumsData), db))
    localArtistsAlbums.save(data=localArtistsAlbumsData)
    if len(searchedForErrors) > 0:
        print("Saving {0} {1} Errors".format(len(searchedForErrors), db))
        errors.save(data=searchedForErrors)

# %%
from lib.jiosaavn import moveLocalFiles
#moveLocalFiles()

# %% [markdown]
# # Download Artist Songs Data

# %%
mio   = jiosaavn.MusicDBIO(verbose=False,local=True,mkDirs=False)
webio = jiosaavn.RawWebData(debug=False)

# %%
useCountsData = True
if useCountsData is True:
    artistNames = io.get('tabs.p').sort_values(by="NumAlbums", ascending=False).reset_index()
    artistNames.index = artistNames["Song"].map(getID)
    artistNames.index.name = ""
    localArtistsSongsData = localArtistsSongs.get()
    artistNamesToGet = artistNames[~artistNames.index.isin(localArtistsSongsData.keys())][["Name", "Song"]]

print("# {0} Search Results".format(db))
print("#   Available Names:      {0}".format(len(artistNames)))
print("#   Known Artist Names:   {0}".format(len(localArtistsSongsData)))
print("#   Artist Names To Get:  {0}".format(len(artistNamesToGet)))

#   Artist Names To Get:  32921
#   Artist Names To Get:  26321
#   Artist Names To Get:  15646

# %%
from timeutils import Timestat, TermTime

ts = Timestat("Getting {0} ArtistIDs".format(db))
#tt = TermTime("tomorrow", "9:50am")
tt = TermTime("today", "10:00pm")
maxN = 50000000

n  = 0
localArtistsSongsData = localArtistsSongs.get()
searchedForErrors = errors.get()

for i,(artistID,row) in enumerate(artistNamesToGet.iterrows()):
    artistName     = row["Name"]
    artistsongURL  = row["Song"]
    #artistSongURL   = row["Song"]
    #artistBioURL    = row["Bio"]
    if localArtistsSongsData.get(artistID) is not None:
        continue
    #if searchedForErrors.get(artistID) is not None:
    #    continue

    response = webio.getArtistData(artistName=artistName, artistURL=artistsongURL)
    if response is None or len(response) == 0:
        print("Error ==> {0}".format((artistID,artistName)))
        searchedForErrors[artistID] = artistName
        errors.save(data=searchedForErrors)
        webio.sleep(5)
        continue
        
    mio.data.saveRawArtistSongData(data=response, modval=mio.getModVal(artistID), dbID=artistID)
    localArtistsSongsData[artistID] = artistName
    webio.sleep(5.0)
    n += 1
        
    if n % 25 == 0:
        print("="*150)
        ts.update(n=n)
        print("Saving {0} {1} Artists Data".format(len(localArtistsSongsData), db))
        localArtistsSongs.save(data=localArtistsSongsData)
        print("="*150)
        webio.wait(5.0)
        if tt.isFinished():
            break
    
if True:
    ts.stop()
    print("Saving {0} {1} Artists Data".format(len(localArtistsSongsData), db))
    localArtistsSongs.save(data=localArtistsSongsData)
    if len(searchedForErrors) > 0:
        print("Saving {0} {1} Errors".format(len(searchedForErrors), db))
        errors.save(data=searchedForErrors)

# %%
from lib.jiosaavn import moveLocalFiles
moveLocalFiles()

# %%
mio   = jiosaavn.MusicDBIO(verbose=False)
for modVal in range(97,100):
    mio.prd.parseSongData(modVal)

# %%
from lib import jiosaavn
#jiosaavn.moveLocalFiles()
#jiosaavn.removeLocalFiles()

from utils import PoolIO
pio = PoolIO("JioSaavn")
pio.parse()
pio.merge()
pio.meta()
pio.sum()
pio.search()

# %%
localArtistsDict  = localArtists.get()
del localArtistsDict['PhqWQ1jM8VQ_']
localArtists.save(data=localArtistsDict)

# %%
from lib.jiosaavn import RawDBData
rdbData = RawDBData()
rdbData.getArtistData("/Volumes/Piggy/Discog/artists-jiosaavn/98/PhqWQ1jM8VQ_.p", verbose=True)

# %%
#from lib.jiosaavn import moveLocalFiles
moveLocalFiles()

# %% [markdown]
# # Create Starter

# %%
from collections import Counter
from ioutils import FileIO, HTMLIO
io = FileIO()
hio = HTMLIO()
cntr = Counter()
refs = []
mio   = jiosaavn.MusicDBIO(verbose=False,local=False,mkDirs=False)
for modVal in range(100):    
    for ifile in mio.dir.getRawModValDataDir(modVal).glob("*.p", debug=False):
        bsdata = hio.get(io.get(ifile))
        for ref in bsdata.findAll("a"):
            href = ref.get('href')
            if isinstance(href,str) and "/artist/" in href:
                title = ref.get('title')
                text  = ref.get('text')
                if isinstance(title, str):
                    name = title
                elif isinstance(text, str):
                    name = text
                else:
                    name = ref.text
                artistID = getID(href)
                if name in ["More", "Artist Albums", "Artist Songs", "Log In", "Artist Biography", "Artist Overview", "Sign Up"]:
                    continue
                if artistID is None:
                    continue
                if len(artistID) < 2:
                    continue
                refs.append({"Name": name, "Ref": href})
    if (modVal+1) % 5 == 0:
        print(modVal+1,'\t',len(refs))

#100 	 28895
#100 	 58338
#100 	 150028
#100 	 382436
#100 	 682420
#100 	 1049429
#100 	 1614663

# %%
refs = []
from listUtils import getFlatList
mio  = jiosaavn.MusicDBIO(verbose=False,local=False,mkDirs=False)
for modVal in range(100):
    modValData = mio.data.getModValData(modVal)
    refs += getFlatList(modValData.apply(lambda rData: rData.profile.extra["PageRefs"]).values)
    if (modVal+1) % 10 == 0:
        print(modVal+1,'\t',len(refs))
                
# 100 	 1725435
# 100 	 2260112

# %%
from pandas import DataFrame, merge
df = DataFrame(refs).rename(columns={"URL": "Ref"})
vc = df["Ref"].value_counts()
df = merge(df.drop_duplicates(), DataFrame(vc).reset_index().rename(columns={"index": "Ref", "Ref": "Num"}), on="Ref").sort_values(by="Num", ascending=False)
df = df[~df["Name"].isin(["More", "Artist Albums", "Artist Songs", "Log In", "Artist Biography", "Artist Overview", "Sign Up"])]
df.index = df["Ref"].apply(getID)
df.index.name = ""

# %%
starterData = {}
mio   = jiosaavn.MusicDBIO(verbose=False)
for artistID,row in mio.data.getSearchArtistData().iterrows():
    if artistID is None or len(artistID) == 0:
        continue
    if starterData.get(artistID) is None:
        starterData[artistID] = row
    else:
        starterData[artistID]["Num"] += row["Num"]
print(len(starterData))
for artistID,row in df.iterrows():
    if artistID is None or len(artistID) == 0:
        continue
    if starterData.get(artistID) is None:
        starterData[artistID] = row
    else:
        starterData[artistID]["Num"] += row["Num"]
#starterData["ii7np5m15sY_"] = Series({"Name": "Twinbeatz", "Ref": "/artist/twinbeatz/ii7np5m15sY_", "Num": 0})
print(len(starterData))
df = DataFrame(starterData).T
mio.data.saveSearchArtistData(data=df)

# %%
https://www.jiosaavn.com/artist/twinbeatz/ii7np5m15sY_

# %%
df
